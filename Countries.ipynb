# %% [markdown]
# # Countries population Growth Comparison

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("countries.csv")

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
data.head()
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
#plt.plot(data.country, data.population / 10 ** 6 )
#plt.legend(['country'])
#plt.title("Country Population")
#plt.ylabel("Population")
#plt.xlabel("Country")
#plt.show()

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# Compare the paopulation growth in the US and China

# %%
us = data[data.country == 'United States']

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = data[data.country == 'China']

# %%
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population /10**6)
plt.legend(['United States', 'China'])
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()

# %%
us.population
# Out:
# 1608    157553000
# 1609    171984000
# 1610    186538000
# 1611    198712000
# 1612    209896000
# 1613    220239000
# 1614    232187835
# 1615    242803533
# 1616    256894189
# 1617    272911760
# 1618    287675526
# 1619    301139947
# Name: population, dtype: int64

# %%
us.population / us.population.iloc[0]
# Out:
# 1608    1.000000
# 1609    1.091595
# 1610    1.183970
# 1611    1.261239
# 1612    1.332225
# 1613    1.397872
# 1614    1.473713
# 1615    1.541091
# 1616    1.630526
# 1617    1.732190
# 1618    1.825897
# 1619    1.911356
# Name: population, dtype: float64

# %%
us.population / us.population.iloc[0] * 100
# Out:
# 1608    100.000000
# 1609    109.159457
# 1610    118.396984
# 1611    126.123908
# 1612    133.222471
# 1613    139.787246
# 1614    147.371256
# 1615    154.109114
# 1616    163.052553
# 1617    173.219018
# 1618    182.589685
# 1619    191.135648
# Name: population, dtype: float64

# %%
plt.plot(us.year, us.population / us.population.iloc[0] * 100)
plt.plot(china.year, china.population / china.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.legend(['United States', 'China'])
plt.xlabel("Year")
plt.ylabel("Population growth (first year = 100)")
plt.show()

# %%
pakistan = data[data.country == 'Pakistan']
ind = data[data.country == 'India']

# %%
pakistan
# Out:
#        country  year  population
# 1164  Pakistan  1952    41346560
# 1165  Pakistan  1957    46679944
# 1166  Pakistan  1962    53100671
# 1167  Pakistan  1967    60641899
# 1168  Pakistan  1972    69325921
# 1169  Pakistan  1977    78152686
# 1170  Pakistan  1982    91462088
# 1171  Pakistan  1987   105186881
# 1172  Pakistan  1992   120065004
# 1173  Pakistan  1997   135564834
# 1174  Pakistan  2002   153403524
# 1175  Pakistan  2007   169270617

# %%
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
plt.plot(pakistan.year, pakistan.population / 10 ** 6)
plt.plot(ind.year, ind.population / 10 ** 6)
plt.legend(['pakistan', 'ind'])
plt.title("Pakistan population growth")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
ind = data[data.country == 'India']

# %%
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
data.year
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
pakistan.population / pakistan.population.iloc[0]
# Out:
# 1164    1.000000
# 1165    1.128992
# 1166    1.284283
# 1167    1.466673
# 1168    1.676703
# 1169    1.890186
# 1170    2.212085
# 1171    2.544030
# 1172    2.903869
# 1173    3.278745
# 1174    3.710188
# 1175    4.093947
# Name: population, dtype: float64

# %%
ind.population / ind.population.iloc[0]
# Out:
# 696    1.000000
# 697    1.099462
# 698    1.220430
# 699    1.360215
# 700    1.524194
# 701    1.704301
# 702    1.903226
# 703    2.118280
# 704    2.344086
# 705    2.577957
# 706    2.780034
# 707    2.984936
# Name: population, dtype: float64

# %%
bangladesh = data[data.country == 'Bangladesh']

# %%
bangladesh
# Out:
#         country  year  population
# 96   Bangladesh  1952    46886859
# 97   Bangladesh  1957    51365468
# 98   Bangladesh  1962    56839289
# 99   Bangladesh  1967    62821884
# 100  Bangladesh  1972    70759295
# 101  Bangladesh  1977    80428306
# 102  Bangladesh  1982    93074406
# 103  Bangladesh  1987   103764241
# 104  Bangladesh  1992   113704579
# 105  Bangladesh  1997   123315288
# 106  Bangladesh  2002   135656790
# 107  Bangladesh  2007   150448339

# %%
bangladesh.population / bangladesh.iloc[0]
# Out:
# 96            NaN
# 97            NaN
# 98            NaN
# 99            NaN
# 100           NaN
# 101           NaN
# 102           NaN
# 103           NaN
# 104           NaN
# 105           NaN
# 106           NaN
# 107           NaN
# country       NaN
# population    NaN
# year          NaN
# dtype: object

# %%
ksa = data[data.country == 'Saudi Arabia']

# %%
ksa
# Out:
#            country  year  population
# 1308  Saudi Arabia  1952     4005677
# 1309  Saudi Arabia  1957     4419650
# 1310  Saudi Arabia  1962     4943029
# 1311  Saudi Arabia  1967     5618198
# 1312  Saudi Arabia  1972     6472756
# 1313  Saudi Arabia  1977     8128505
# 1314  Saudi Arabia  1982    11254672
# 1315  Saudi Arabia  1987    14619745
# 1316  Saudi Arabia  1992    16945857
# 1317  Saudi Arabia  1997    21229759
# 1318  Saudi Arabia  2002    24501530
# 1319  Saudi Arabia  2007    27601038

# %%
ksa.population / ksa.population.iloc[0]
# Out:
# 1308    1.000000
# 1309    1.103347
# 1310    1.234006
# 1311    1.402559
# 1312    1.615896
# 1313    2.029246
# 1314    2.809680
# 1315    3.649756
# 1316    4.230460
# 1317    5.299918
# 1318    6.116701
# 1319    6.890480
# Name: population, dtype: float64

# %%
china = data[data.country == 'China']

# %%
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
china.population / china.population.iloc[0]
# Out:
# 288    1.000000
# 289    1.145874
# 290    1.196861
# 291    1.356461
# 292    1.549679
# 293    1.696058
# 294    1.798214
# 295    1.948780
# 296    2.094277
# 297    2.211317
# 298    2.301787
# 299    2.370609
# Name: population, dtype: float64

# %%
afgh = data[data.country == 'Afghanistan']

# %%
afgh
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
china.population / china.population.iloc[0]
# Out:
# 288    1.000000
# 289    1.145874
# 290    1.196861
# 291    1.356461
# 292    1.549679
# 293    1.696058
# 294    1.798214
# 295    1.948780
# 296    2.094277
# 297    2.211317
# 298    2.301787
# 299    2.370609
# Name: population, dtype: float64

# %%
egypt = data[data.country == 'Egypt']

# %%
egypt.population / egypt.population.iloc[0]
# Out:
# 456    1.000000
# 457    1.125383
# 458    1.267737
# 459    1.425584
# 460    1.566257
# 461    1.745188
# 462    2.055581
# 463    2.375842
# 464    2.672968
# 465    2.975898
# 466    3.298904
# 467    3.611728
# Name: population, dtype: float64

# %%
plt.plot(pakistan.year, pakistan.population / pakistan.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.plot(bangladesh.year, bangladesh.population / bangladesh.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.plot(ind.year, ind.population / ind.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.plot(ksa.year, ksa.population / ksa.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.plot(china.year, china.population / china.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.plot(afgh.year, afgh.population / afgh.population.iloc[0] * 100,marker = 'o' ,linestyle = 'solid')
plt.plot(egypt.year,egypt.population / egypt.population.iloc[0] * 100, marker = 0, linestyle = 'solid')
plt.legend(['pakistan', 'ind', 'bangladesh', 'ksa', 'china', 'afgh','egypt'])
plt.xlabel("Year")
plt.ylabel("Population growth (first year = 100)")
plt.show()
